# %% [markdown]
# # **Project Name**    -      Stock Price Prediction

# %% [markdown]
# ##### **Project Type**    -  Data preprocessing, feature engineering
# ##### **Contribution**    - Team
# ##### **Team Member 1 -**Vishwash Bharti
# ##### **Team Member 2 -**Vishesh Singal
# ##### **Team Member 3 -**Yatharth
# ##### **Team Member 4 -**Vivek Anand

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# In the era of rapid technological advancements, artificial intelligence (AI) has become a game-changer across various industries. This project dives into the exciting realm of financial data analysis by focusing on Tesla stock prices. The primary objective is to leverage AI techniques, specifically advanced time series forecasting algorithms, to gain insights into Tesla's stock behavior and make informed predictions.
#
# Project Overview:
#
# Tesla, Inc., a pioneer in electric vehicles and renewable energy solutions, has witnessed unprecedented growth and volatility in its stock prices. Analyzing this data poses a unique challenge due to its temporal nature and susceptibility to market dynamics. The project employs AI methodologies to extract valuable information, enabling investors, financial analysts, and enthusiasts to make more informed decisions.
#
# Key Components of the Project:
#
#     Data Collection:
#     The project initiates with the collection of historical Tesla stock price data from reliable financial sources. The dataset encompasses daily closing prices, volume, and other relevant financial indicators. This raw data serves as the foundation for subsequent analysis and model development.
#
#     Data Preprocessing:
#     Raw financial data often contains irregularities, missing values, or outliers. Data preprocessing is crucial to ensure the accuracy and reliability of subsequent analyses. Techniques such as handling missing data, addressing outliers, and normalizing values are applied to create a clean and standardized dataset.
#
#     Feature Engineering:
#     Feature engineering plays a pivotal role in enhancing the predictive power of models. Beyond traditional stock metrics, additional features are engineered to capture latent patterns and trends. Technical indicators, moving averages, and other financial metrics are incorporated to enrich the dataset and empower models with more robust information.
#
#     Exploratory Data Analysis (EDA):
#     EDA is conducted to unveil inherent patterns and relationships within the data. Visualizations, statistical summaries, and correlation analyses aid in understanding the historical behavior of Tesla stock prices. Insights gained during this phase inform subsequent modeling decisions.
#
#     Algorithmic Experimentation:
#     The project explores three prominent time series forecasting algorithms: ARIMA (AutoRegressive Integrated Moving Average), LSTM (Long Short-Term Memory), and Prophet. Each algorithm brings unique strengths to the table. ARIMA leverages statistical methods, LSTM utilizes deep learning, and Prophet, developed by Facebook, is adept at handling daily patterns in time series data.
#
#     Model Training and Evaluation:
#     The selected algorithms are trained on historical data and evaluated using appropriate performance metrics. The goal is to develop models that accurately capture the temporal dependencies in Tesla stock prices. The evaluation phase involves comparing model predictions against actual stock prices to gauge their effectiveness.
#
#     Hyperparameter Tuning:
#     Fine-tuning the parameters of the selected models is crucial for optimizing performance. Hyperparameter tuning is carried out using techniques such as grid search or random search to identify the most effective configuration for each algorithm.
#
#     Prediction and Visualization:
#     Once trained and validated, the models are employed to make future predictions. Predictions are visualized alongside actual stock prices to provide a clear comparison. This visual representation aids in interpreting the model's efficacy and understanding its predictive capabilities.
#
# Expected Outcomes:
#
#     Accurate Predictions: The project aims to develop models that provide accurate short to medium-term predictions of Tesla stock prices, aiding investors in decision-making.
#
#     Insightful Analysis: Through EDA and feature engineering, the project endeavors to uncover valuable insights into the factors influencing Tesla's stock behavior.
#
#     Comparative Analysis: A comparative analysis of the three algorithms (ARIMA, LSTM, Prophet) will be presented, highlighting their respective strengths and weaknesses in predicting Tesla stock prices.
#
# Conclusion:
#
# In conclusion, this AI-driven project delves into the dynamic world of financial data analysis, specifically focusing on Tesla stock prices. Through meticulous data preprocessing, feature engineering, and experimentation with advanced time series forecasting algorithms, the project seeks to provide a comprehensive analysis and prediction framework. The ultimate goal is to empower stakeholders with valuable insights, facilitating more informed decision-making in the dynamic realm of financial markets.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Analyzing Tesla stock prices presents a complex challenge due to the dynamic nature of financial markets. The project aims to harness the power of artificial intelligence, employing advanced time series forecasting techniques like ARIMA, LSTM, and Prophet. The objective is to develop models that accurately predict Tesla stock prices, providing valuable insights for investors and financial analysts in navigating the unpredictable nature of the stock market.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
# from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %% [markdown]
# ### Dataset Loading

# %%
df = pd.read_csv("/content/Tesla.csv")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df
# Out:
#            Date        Open        High         Low       Close    Volume  \
# 0     6/29/2010   19.000000   25.000000   17.540001   23.889999  18766300
# 1     6/30/2010   25.790001   30.420000   23.299999   23.830000  17187100
# 2      7/1/2010   25.000000   25.920000   20.270000   21.959999   8218800
# 3      7/2/2010   23.000000   23.100000   18.709999   19.200001   5139800
# 4      7/6/2010   20.000000   20.000000   15.830000   16.110001   6866900
# ...         ...         ...         ...         ...         ...       ...
# 1687  3/13/2017  244.820007  246.850006  242.779999  246.169998   3010700
# 1688  3/14/2017  246.110001  258.119995  246.020004  258.000000   7575500
# 1689  3/15/2017  257.000000  261.000000  254.270004  255.729996   4816600
# 1690  3/16/2017  262.399994  265.750000  259.059998  262.049988   7100400
# 1691  3/17/2017  264.000000  265.329987  261.200012  261.500000   6475900
#
#        Adj Close
# 0      23.889999
# 1      23.830000
# 2      21.959999
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (1692, 7)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1692 entries, 0 to 1691
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1692 non-null   object
#  1   Open       1692 non-null   float64
#  2   High       1692 non-null   float64
#  3   Low        1692 non-null   float64
#  4   Close      1692 non-null   float64
#  5   Volume     1692 non-null   int64
#  6   Adj Close  1692 non-null   float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 92.7+ KB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Volume       0
# Adj Close    0
# dtype: int64

# %%
# Visualizing the missing values
plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cbar=True, cmap='coolwarm')

plt.title('Missing Values Heatmap')
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# This dataset on Tesla stock is a collection of historical data related to Tesla, Inc.'s stock performance. It includes various financial indicators and metrics that are crucial for analyzing the dynamics of the stock market. The dataset is organized in tabular form, with rows representing different dates and columns representing various features.
#
# The dataset provides information about :
#
# 1.   Date
#
# 2.   Closing Price
#
# 3. Volume
#
# 4. Opening Price
#
# 5. Highest Price
#
# 6. Lowest Price.
# 7. Adjusted Closing Price

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  1692.000000  1692.000000  1692.000000  1692.000000  1.692000e+03
# mean    132.441572   134.769698   129.996223   132.428658  4.270741e+06
# std      94.309923    95.694914    92.855227    94.313187  4.295971e+06
# min      16.139999    16.629999    14.980000    15.800000  1.185000e+05
# 25%      30.000000    30.650000    29.215000    29.884999  1.194350e+06
# 50%     156.334999   162.370002   153.150002   158.160004  3.180700e+06
# 75%     220.557495   224.099999   217.119999   220.022503  5.662100e+06
# max     287.670013   291.420013   280.399994   286.040009  3.716390e+07
#
#          Adj Close
# count  1692.000000
# mean    132.428658
# std      94.313187
# min      15.800000
# 25%      29.884999
# 50%     158.160004
# 75%     220.022503
# max     286.040009

# %% [markdown]
# ### Variables Description

# %% [markdown]
#  Date: The dataset is likely to have a temporal component, with each entry  representing a specific date.
#
# 2.   Closing Price: The closing price of Tesla stock on each date, a key metric    for investors.
#
# 3. Volume: The trading volume of Tesla stock, indicating market activity.
#
# 4. Opening Price : The opening price of Tesla stock on each date, a key metric    for investors.
#
# 5. Highest Price : The Highest price of Tesla stock on each date, providing a very important metric to the investors to make their investement decisions.
#
# 6. Lowest Price  :  The Lowest price of Tesla stock on each date, providing a very important metric to the investors to make their investement decisions.
#
# 7. Adjusted Clsoing Price  : The Adjusted Closing Price is a financial metric that represents the adjusted value of a stock's closing price. It is commonly used in the analysis of historical stock prices and is particularly important for understanding an investment's performance over time.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df['Open'].unique()
df['Close'].unique()
df['High'].unique()
df['Low'].unique()
df['Volume'].unique()
df['Date'].unique()
df['Adj Close'].unique()
# Out:
# array([ 23.889999,  23.83    ,  21.959999, ..., 255.729996, 262.049988,
#        261.5     ])

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
df.dropna(inplace=True)

# Fill missing values with the mean of the column
# df.fillna(df.mean(), inplace=True)
# Remove duplicate rows
df.drop_duplicates(inplace=True)
# Identify numerical columns
numerical_columns = df.select_dtypes(include=['float64', 'int64']).columns

# Initialize the MinMaxScaler
# # scaler = MinMaxScaler()
df['Date'] = pd.to_datetime(df['Date'])

# Group by year and calculate summary statistics for each year
df_yearly = df.groupby(df['Date'].dt.year).agg({'Open': 'mean', 'Close':'mean', 'High': 'mean','Low' : 'mean','Adj Close' : 'mean','Volume':'mean'}).reset_index()

# Fit and transform the entire dataset
# df = df.groupby(df['Date'].dt.year)['Price'].mean().reset_index()
# df[numerical_columns] = scaler.fit_transform(df[numerical_columns])
df_main=df
df=df_yearly

df
# Out:
#    Date        Open       Close        High         Low   Adj Close  \
# 0  2010   23.408000   23.341846   24.077231   22.646077   23.341846
# 1  2011   26.821984   26.804762   27.380238   26.194167   26.804762
# 2  2012   31.203120   31.168600   31.809160   30.545880   31.168600
# 3  2013  104.416428  104.401230  106.853016  101.779881  104.401230
# 4  2014  223.415397  223.329088  227.449881  219.206111  223.329088
# 5  2015  229.831944  230.042898  233.381666  226.270635  230.042898
# 6  2016  210.058452  209.767262  213.433492  206.286151  209.767262
# 7  2017  250.426539  251.301924  253.969808  247.681539  251.301924
#
#          Volume
# 0  1.579762e+06
# 1  1.290615e+06
# 2  1.229796e+06
# 3  8.407722e+06
# 4  6.913973e+06
# 5  4.317792e+06
# 6  4.611444e+06
# 7  5.323187e+06

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
#     Handling Missing Values:
#         The dropna(inplace=True) method is used to remove rows with missing values. This can be effective if the number of missing values is relatively small compared to the overall dataset.
#
#     Filling Missing Values with Mean values/Imputing missing values:
#         The fillna(df.mean(), inplace=True) method is employed to fill missing values with the mean of each respective column. Imputing missing values with the mean is a common strategy, especially for numerical features. It helps retain data integrity while filling in gaps.
#
#     Removing Duplicate Rows:
#         The drop_duplicates(inplace=True) method is used to remove duplicate rows from the dataset. Removing duplicates ensures that each observation is unique, preventing biases in analysis.
#
#     Normalizing Numerical Columns:
#         The code identifies numerical columns using select_dtypes and then uses the MinMaxScaler to normalize these columns. Normalization scales numerical features to a standard range (typically between 0 and 1). This is essential for machine learning algorithms that are sensitive to the scale of input features.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# Chart - 1

# %%
# Chart - 1 visualization code
y = df['Open']
x = df['Date']

# Plot the data
plt.figure(figsize=(10, 10))
# plt.scatter(x, y,alpha = 0.5)
plt.plot(x, y)
# Set labels for the x and y axes
plt.ylabel('Average Opening Price')
plt.xlabel('Year')

# Set a title for the plot
plt.title('Average Opening Prices variation with Year')

# Display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  Line plots are suitable for showing continuous data, such as stock prices, where each data point represents a specific point in time. The lines in the plot connect these points, helping viewers to perceive the overall trend more easily.Answer Here.

# %% [markdown]
# We found the variation of opening prizes with time. The prices
# fluctuated but in the long run the prices increased.
# 1.   In the beginning of the given timeframe during the years between 2010 to 2012 the opening prices are the lowest and are fairly consistent throughout.There is a slight increase during this time.
# 1.   In the year 2012 there is a sudden and shar rise in the opening prices
# 2.   Between the years 2012 to 2014 there is a sharp rise in opening prices .
# 3.   Between 2014 and 2015 there isn't much growth in terms of opening prices. The prices remain fairly consistent throughout.
# 4.   Between 2015 to 2016 there is a decrease between 2015 to 2016. The prices during this time are lower than 2014.
# 5.   The prices start increasing again from 2016 and are rising consistently until 2017.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We found the variation of opening prizes with time. The prices
# fluctuated but in the long run the prices increased.
# 1.   In the beginning of the given timeframe during the years between 2010 to 2012 the opening prices are the lowest and are fairly consistent throughout.There is a slight increase during this time.
# 1.   In the year 2012 there is a sudden and shar rise in the opening prices
# 2.   Between the years 2012 to 2014 there is a sharp rise in opening prices .
# 3.   Between 2014 and 2015 there isn't much growth in terms of opening prices. The prices remain fairly consistent throughout.
# 4.   Between 2015 to 2016 there is a decrease between 2015 to 2016. The prices during this time are lower than 2014.
# 5.   The prices start increasing again from 2016 and are rising consistently until 2017.
#
#
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Yes, the gained insights can potentially help create a positive business impact. Understanding the historical trends of Tesla stock opening prices can inform investment strategies, timing of purchases, and overall decision-making processes for investors and stakeholders. This knowledge may enable better risk management and potentially lead to more profitable investment decisions in the future.
#
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# There aren't any major insights that lead to negative growth. Although in between there is sudden drop in prices but in the long run the prices have risen substantially

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
y = df['Close']
x = df['Date']

# Plot the data
plt.figure(figsize=(10, 10))
plt.plot(x, y,alpha = 0.5)

# Set labels for the x and y axes
plt.ylabel('Average Closing Price')
plt.xlabel('Year')

# Set a title for the plot
plt.title('Average Closing Prices variation with Year')

# Display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Line plots are suitable for showing continuous data, such as stock prices, where each data point represents a specific point in time. The lines in the plot connect these points, helping viewers to perceive the overall trend more easily.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We found the variation of closing prizes with time. The prices
# fluctuated but in the long run the prices increased.
# 1.   In the beginning of the given timeframe during the years between 2010 to 2012 the closing prices are the lowest and are fairly consistent throughout.There is a slight increase during this time.
# 1.   In the year 2012 there is a sudden and shar rise in the closing prices
# 2.   Between the years 2012 to 2014 there is a sharp rise in closing prices .
# 3.   Between 2014 and 2015 there isn't much growth in terms of closing prices. The prices remain fairly consistent throughout.
# 4.   Between 2015 to 2016 there is a decrease between 2015 to 2016. The prices during this time are lower than 2014.
# 5.   The prices start increasing again from 2016 and are rising consistently until 2017.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Yes, the gained insights can potentially help create a positive business impact. Understanding the historical trends of stock closing prices can inform investment strategies, timing of purchases, and overall decision-making processes for investors and stakeholders. This knowledge may enable better risk management and potentially lead to more profitable investment decisions in the future.
#
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# There aren't any major insights that lead to negative growth. Although in between there is slight drop in prices but in the long run the prices have risen substantially

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code

y = df['High']
y2 = df['Low']

x = df['Date']

# Plot the data
plt.figure(figsize=(10, 10))
plt.plot(x, y,alpha = 0.5)
plt.plot(x,y2,alpha = 0.5)

# Set labels for the x and y axes
plt.ylabel('Highest Price and Lowest Price')
plt.xlabel('Year')


# Set a title for the plot
plt.title('Average Highest and Lowest Price variation with Year')

# Display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Line plots are suitable for showing continuous data, such as stock prices, where each data point represents a specific point in time. The lines in the plot connect these points, helping viewers to perceive the overall trend more easily.
# It Shows the range of price fluctuations for Tesla stock over time, helping to identify volatility and price extremes.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We found the variation of highest and lowest prizes with time. The prices
# fluctuated but in the long run the prices increased.
# 1.   In the beginning of the given timeframe during the years between 2010 to 2012 the highest and lowest prices are at their lowest avlue and are fairly consistent throughout.There is a slight increase during this time.
# 1.   In the year 2012 there is a sudden and sharp rise in the values
# 2.   Between the years 2012 to 2014 there is a sharp rise in values .
# 3.   Between 2014 and 2015 there isn't much growth in terms of values. The prices remain fairly consistent throughout.
# 4.   Between 2015 to 2016 there is a decrease between 2015 to 2016. The values during this time are lower than 2014.
# 5.   The values start increasing again from 2016 and are rising consistently until 2017.
#
# Overall we see that there isnt a large difference between highest and lowest prices. The difference is small from 2010 to 2014 after 2014 the difference has increased.
#
# The highest gap between highest and lowest prices was recorded in 2014-2015

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Yes, the gained insights can potentially help create a positive business impact. Understanding the historical trends of stock highest prices can inform investment strategies, timing of purchases, and overall decision-making processes for investors and stakeholders. This knowledge may enable better risk management and potentially lead to more profitable investment decisions in the future.
#
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# There aren't any major insights that lead to negative growth. Although in between there is slight drop in prices but in the long run the prices have risen substantially

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
y = df['Adj Close']
x = df['Date']

# Plot the data
plt.figure(figsize=(10, 10))
plt.plot(x, y,alpha = 0.5)

# Set labels for the x and y axes
plt.ylabel('Adjusted Closing Price')
plt.xlabel('Year')

# Set a title for the plot
plt.title('Adjusted Closing Prices variation with Year')

# Display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Line plots are suitable for showing continuous data, such as stock prices, where each data point represents a specific point in time. The lines in the plot connect these points, helping viewers to perceive the overall trend more easily.
#
# Adjusted closing prices account for corporate actions such as dividends and stock splits, providing a more accurate representation of the stock's true value over time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We found the variation of adjusted closing prices with time. The prices
# fluctuated but in the long run the prices increased.
# 1.   In the beginning of the given timeframe during the years between 2010 to 2012 the prices are the lowest and are fairly consistent throughout.There is a slight increase during this time.
# 1.   In the year 2012 there is a sudden and shar rise in the prices
# 2.   Between the years 2012 to 2014 there is a sharp rise in prices .
# 3.   Between 2014 and 2015 there isn't much growth in terms of  prices. The prices remain fairly consistent throughout.
# 4.   Between 2015 to 2016 there is a decrease between 2015 to 2016. The prices during this time are lower than 2014.
# 5.   The prices start increasing again from 2016 and are rising consistently until 2017.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# There aren't any major insights that lead to negative growth. Although in between there is slight drop in prices but in the long run the prices have risen substantially

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
y = df['Volume']
x = df['Date']

# Plot the data
plt.figure(figsize=(10, 10))
plt.bar(x, y,alpha = 0.5)

# Set labels for the x and y axes
plt.ylabel('Volume')
plt.xlabel('Date')

# Set a title for the plot
plt.title('Volume traded variation with Date')

# Display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar plot helps Visualizes the trading volume of stock over time, indicating periods of high or low trading activity, which can be correlated with price movements.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We observed the follwoing  :
#
#
# 1.   The volume of shares traded is very low in 2010 and is slighly decreasing from 2010 to 2011
# 2.   From 2011 to 2012 there is further decrease in the volume traded but the decrease is at a slightly lesser rate than 2010 to 2011. In 2011 the least no of shares were traded during this time period according to the data.
# 3. In 2012 there is sharp rise in the volume of shares traded .
# 4. The no. skyrocketed between 2012 and 2013. Reaching the highest volumne of shares traded by the end of 2012.
# 5. Between the years 2013 and 2015 the volume of shares traded decreased.
# 6. In 2015 the volume started increasing again at a slow rate
# 7. The growth continued in the year 2016 at a slightly faster rate than last year

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
#
# Yes, these insights can potentially have a positive business impact. Understanding the trends in the volume of shares traded for Tesla stock can provide valuable information for market analysis and forecasting. Investors and traders can use this data to gauge market sentiment, identify potential trading opportunities, and make more informed decisions. Additionally, businesses involved in financial services or investment management can leverage these insights to optimize trading strategies and enhance portfolio management techniques, potentially leading to improved performance and profitability.
#
#
#
#
# Are there any insights that lead to negative growth? Justify with specific reason.
#
#
# Yes, one insight that indicates negative growth is the decrease in the volume of shares traded between 2013 and 2015. This trend suggests a decline in market activity and investor interest in Tesla stock during this period. Several factors could contribute to this negative growth:
#
# 1. Market Sentiment
#
# 2. Economic Conditions:
#
# 3. Industry Factors
#
# 4. Regulatory Changes
#
# Overall, a sustained decrease in trading volumes over multiple years suggests a period of negative growth or stagnation in investor interest, which could have implications for the company's stock performance and overall market dynamics.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code


# Plotting histogram
plt.figure(figsize=(10, 6))
plt.hist(df_main['Close'], bins=30, color='skyblue', edgecolor='black')
plt.title('Distribution of Closing Prices')
plt.xlabel('  Closing Price')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  We used histogram because it is useful for displaying the distribution of a single variable, such as the distribution of stock prices.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. We found that the data is positively skewed
# 2. The spread of the histogram is qyuite wide suggesting a broader range of closing prices
# 3. The most common closing prices are in the range 0 to 50.
# 4. Most days the closing prices are in the range 150 - 250

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes it helps us in the following ways
#  Understanding Skewness: Recognizing that the data is positively skewed provides insights into the distribution of closing prices. This understanding can guide investment strategies, risk management decisions, and portfolio diversification efforts, helping stakeholders better navigate market dynamics.
#
# Wide Spread: Acknowledging the wide spread of closing prices suggests significant variability in the market, which may present opportunities for arbitrage or strategic investments. Traders and investors can leverage this insight to optimize trading strategies and capitalize on price discrepancies.
#
# Identifying Common Price Ranges: Recognizing that the most common closing prices fall within the range of 0 to 50 highlights the importance of monitoring and analyzing movements within this range. Businesses can tailor their strategies and offerings to accommodate customer preferences and market trends within this price range.
#
# Noting the Range of 150 - 250: Observing that most closing prices cluster in the range of 150 to 250 provides valuable information for setting expectations and forecasting future price movements. Businesses can use this insight to anticipate market trends, adjust pricing strategies, and make informed decisions regarding resource allocation and investment opportunities.
#
# However, it's crucial to consider potential negative implications as well:
#
# Positive Skewness: While positively skewed data can present opportunities for growth, it may also indicate an imbalance or distortion in the market. Extreme values on the higher end of the distribution could lead to increased volatility and risk, potentially resulting in unexpected losses or market disruptions.
#
# Wide Spread and Volatility: The wide spread of closing prices suggests greater market volatility and uncertainty, which could pose challenges for risk management and financial planning. Businesses may need to implement robust risk mitigation strategies to protect against adverse market movements and ensure sustainable growth.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
plt.figure(figsize=(8, 6))
plt.scatter(df_main['Close'], df_main['Volume'], color='skyblue', alpha=1.0)
plt.title('Scatter Plot of Closing Prices vs Volume')
plt.xlabel('Closing Price')
plt.ylabel('Volume')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This plot helps us to examine the relationship between closing price and trading volume, providing insights into the correlation between price movements and trading activity.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. In the closing price range from 175-250  a dense cluster of points suggests that there are many instances where both the closing price and the trading volume fall within a narrow range. This indicates periods of high trading activity where the stock price and trading volume remain relatively consistent.
#
# 2. In the range 50 - 100 there isn't much activity. Infact this range has the least amount of activity meaning when prices were in this range trading activity hasn't been very consistent
# 3. Ironically, the highest volume traded was observed when prices were in the range between 50 - 100.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights offer valuable information for strategic decision-making:
#
# Positive Impact:
#
# Understanding periods of high trading activity in the 175-250 price range can help identify opportunities for capitalizing on market momentum and optimizing trading strategies during these periods.
# Recognizing the highest volume traded in the 50-100 price range can inform strategic pricing decisions and market positioning to attract trading activity despite lower price levels.
# Potential Negative Impact:
#
# The lack of trading activity in the 50-100 price range may indicate lower investor interest or confidence in the stock during those periods. This could potentially lead to negative growth if not addressed through targeted marketing efforts or strategic initiatives to improve market perception.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
plt.figure(figsize=(8, 6))
sns.kdeplot(df_main['Close'], color='skyblue', fill=True)
plt.title('KDE Plot of Closing Prices')
plt.xlabel('Closing Price')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  The KDE plot provides a smoothed representation of the distribution of closing prices, allowing for easier identification of patterns and trends.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. The central tendency of the data is along the range 0-50 meaing the most common closing price range is 0-50
# 2. The amount of closing prices is least in the range 100-150
# 3. The amount of closing prices in the range 150-250 is also high suggesting on alot of days the closing prices were in this range

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Impact:
#
# Understanding the prevalent closing price range (0-50) allows for targeted marketing and product positioning to attract investors interested in stocks within this range.
# Recognizing the high activity range (150-250) provides opportunities to capitalize on market momentum and optimize trading strategies during periods of heightened trading activity.
# Negative Growth:
#
# The low activity range (100-150) suggests a lack of market interest or demand within that price range. Failing to address this could lead to negative growth as the stock may struggle to attract investors or maintain market liquidity within this range.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
plt.figure(figsize=(8, 6))
sns.boxplot(data=df_main['Close'], color='skyblue')
plt.title('Box Plot of Closing Prices')
plt.ylabel('Closing Price')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This plot provides a summary of the distribution of closing prices, including information about central tendency, variability, and potential outliers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. It suggests that the data is positively skewed the median is not centered within the box, indicating skewness in the data. A positive skew means that the data is concentrated on the lower end with a few high values.
# 2. The presence of a long upper whisker suggests that there are outliers or extreme values in the upper range of the dataset that contribute to the skewness.
# 3. Short lower whisker indicates that most of the data points are concentrated in the lower range of values, leading to a relatively compact lower whisker.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Understanding Data Skewness and Outliers:
#
# Recognition of positive skewness and the presence of outliers can enhance pricing strategies and risk management decisions, leading to more informed business strategies.
# Identification of Concentration of Data Points:
#
# Awareness of data concentration in lower ranges enables businesses to tailor marketing strategies and product offerings, potentially increasing customer satisfaction and loyalty.
# Considerations for Negative Growth:
#
# Risk of Overreliance on Outliers:
#
# Failure to properly account for outliers may lead to skewed analysis and suboptimal decision-making, posing a risk to business performance.
# Management of Market Volatility:
#
# Positive skewness and outlier presence may indicate underlying market volatility, necessitating robust risk management practices to mitigate potential negative growth outcomes.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
df_main['Daily_Price_Change'] = df_main['Close'] - df_main['Open']

# Plot histogram of daily price changes
plt.figure(figsize=(10, 6))
plt.hist(df_main['Daily_Price_Change'], bins=30, color='skyblue', edgecolor='black')
plt.title('Histogram of Daily Price Changes')
plt.xlabel('Daily Price Change')
plt.ylabel('Frequency')

plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The histogram of daily price changes offers valuable insights into market trends, risk assessment, and comparative analysis, making it a useful visualization tool for analyzing the Tesla stock dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. A symmetric histogram suggests that there are as many instances of positive price changes (closing price higher than opening price) as there are negative price changes (closing price lower than opening price).
# This balanced distribution indicates that the stock experiences both upward and downward movements with similar frequencies over the period analyzed.
# 2. There are more instances of negative price changes (closing price lower than opening price) compared to positive changes.
# This observation implies that, on average, the stock tends to experience more downward movements or decreases in price on a daily basis.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Balanced Distribution (Symmetric Histogram):
#
# Positive Impact: A symmetric histogram suggests a balanced distribution of positive and negative price changes, indicating that the stock experiences both upward and downward movements with similar frequencies. This insight can help businesses anticipate market dynamics and adjust strategies accordingly to capitalize on both bullish and bearish trends.
# Prevalence of Negative Price Changes:
#
# Negative Growth: The observation that there are more instances of negative price changes compared to positive changes implies a prevailing downtrend or market sentiment biased towards declines in stock price. This could potentially lead to negative growth as it indicates a higher frequency of downward movements, which may adversely affect investor confidence and market performance.

# %% [markdown]
# #### Chart - 11

# %%
df_main['Date'] = pd.to_datetime(df_main['Date'])

# Extract the year from the 'date' column
df_main['year'] = df_main['Date'].dt.year

# Group by year and calculate average closing price for each year
average_closing_by_year = df_main.groupby('year')['Close'].mean()

# Create a bar plot
plt.figure(figsize=(10, 6))
average_closing_by_year.plot(kind='bar', color='skyblue')
plt.title('Average Closing Price by Year')
plt.xlabel('Year')
plt.ylabel('Average Closing Price')
plt.xticks(rotation=45)

plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This Bar plot helps us to analyze the trend of Tesla's average closing prices over different years, providing insights into the stock's historical performance and identifying potential patterns or trends in the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. The highest average closing price is in the year 2017.
# 2. The lowst average closing price is in the year 2010.
# 3. The average closing price has risen substantially over the years.
# 4. The years between 2010 to 2012 the average closing price is relatively low
# 5. In 2013 it rises sharply in 2013 and even more in 2014.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# The insights indicating a steady increase in average closing prices and significant growth spurts in certain years can enhance investor confidence.
# This can attract new investments, potentially leading to increased capital inflow and facilitating business expansion opportunities for Tesla.
# Negative Growth Insights:
#
# The period of relatively low average closing prices between 2010 to 2012 suggests a phase of slower growth or negative performance.
# While this provides historical context, it may not directly lead to negative growth. However, it highlights challenges or subdued periods that need to be addressed strategically.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
df_main['Date'] = pd.to_datetime(df_main['Date'])

# Extract the year from the 'date' column
df_main['year'] = df_main['Date'].dt.year

# Group by year and calculate total trading volume for each year
volume_by_year = df_main.groupby('year')['Volume'].sum()

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(volume_by_year, labels=volume_by_year.index, autopct='%1.1f%%', startangle=140)
plt.title('Trading Volume Distribution by Year')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This pie chart to visualize the distribution of trading volume across different years. A pie chart effectively displays the proportion of trading volume contributed by each year, making it easy to identify which years had a larger or smaller share of the total trading volume. This visualization helps in understanding the relative importance of each year in terms of trading activity, providing insights into historical trading patterns and potential shifts in market dynamics over time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. The years 2013 and 2014 stand out with the highest trading volume percentages, accounting for 29.3% and 24.1% of the total volume, respectively. This suggests periods of heightened market activity and investor interest in stock during these years.
#
# 2. Years 2015 and 2016 demonstrate relatively consistent trading volume percentages, comprising 15.1% and 16.1% of the total volume, respectively. This indicates sustained market participation and stability in trading activity during these periods.
#
# 3. The year 2017 shows a lower trading volume percentage of 3.8%, suggesting a potential decrease in market activity or a shift in investor focus. This could signify a transitional period or the emergence of new market trends impacting trading behavior.
#
# 4. Years 2010 to 2012 exhibit lower trading volume percentages, ranging from 2.8% to 4.5%. This indicates a period of relatively lower market participation or subdued investor interest in Tesla's stock compared to later years.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# The insights gained from the pie chart can help identify periods of heightened market activity and sustained investor interest, such as the years 2013 and 2014.
# Understanding these periods of high trading volume can inform strategic decisions, attract investor confidence, and potentially contribute to positive business impacts such as increased liquidity and market capitalization.
#
# Negative Growth Insights:
#
# The lower trading volume percentages observed in certain years, such as 2017 and the earlier years (2010 to 2012), may indicate periods of subdued market activity or decreased investor interest.
# This could lead to challenges such as reduced liquidity, lower trading activity, and potential volatility in stock prices, which may negatively impact market sentiment and shareholder value.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
df_main['Date'] = pd.to_datetime(df_main['Date'])

# Calculate price change for each day
df_main['price_change'] = df_main['Close'] - df_main['Open']

# Group by year
df_main['year'] = df_main['Date'].dt.year
grouped = df_main.groupby('year')

# Calculate percentage of positive and negative price changes for each year
positive_percentage = grouped.apply(lambda x: (x['price_change'] > 0).mean() * 100)
negative_percentage = 100 - positive_percentage

# Create pie chart for each year
for year in df_main['year'].unique():
    plt.figure(figsize=(6, 6))
    plt.pie([positive_percentage[year], negative_percentage[year]], labels=['Positive Change', 'Negative Change'],
            autopct='%1.1f%%', startangle=140)
    plt.title(f'Price Change Distribution for Year {year}')
    plt.axis('equal')
    plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This pie chart offers a clear and concise overview of the distribution of positive and negative price changes for the entire time period, enabling quick interpretation of the trend and volatility of stock prices over time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. In 2010, the higher percentage of negative price changes (56.2%) suggests that the stock faced challenges or downward pressure, potentially indicating market uncertainties or company-specific issues impacting investor sentiment.
# 2.  In 2011, with 50.4% of the days experiencing positive price changes and 49.6% of the days experiencing negative price changes, it suggests a slightly more favorable market sentiment compared to 2010. This indicates that there might have been improvements or positive developments impacting the stock, leading to a more balanced distribution between upward and downward price movements.
# 3. In 2012, with 53.2% of days experiencing negative price changes and 46.8% experiencing positive price changes, it suggests a predominance of negative sentiment or challenges impacting the stock during that period. This could indicate various factors such as market volatility, economic uncertainty, or company-specific issues leading to more frequent declines in price compared to increases.
# 4.
# In 2013, with an equal distribution of negative (50%) and positive (50%) price changes, it suggests a balanced market sentiment with no clear dominance of either upward or downward price movements. This could indicate a period of stability or neutrality in market conditions, where positive and negative factors may have balanced each other out, resulting in relatively even price changes throughout the year.
# 5. In 2014, with 52.4% of days experiencing negative price changes and 47.6% experiencing positive price changes, it suggests a predominance of negative sentiment or challenges impacting the stock during that period.
# 6. In 2015, with 48.8% of days experiencing negative price changes and 51.2% experiencing positive price changes, it suggests a slightly more positive market sentiment compared to 2014.
# 7.
# In 2016, with 53.2% of days experiencing negative price changes and 46.8% experiencing positive price changes, it suggests a predominance of negative sentiment or challenges impacting the stock during that period.
#
# 8.
# In 2017, with 46.2% of days experiencing negative price changes and 53.8% experiencing positive price changes, it suggests a predominantly positive market sentiment compared to 2016.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# Awareness of positive market sentiment in certain years (e.g., 2011, 2013, 2015, 2017) can guide businesses to capitalize on favorable conditions by potentially increasing investments or expanding operations during these periods.
# Identification of improvements or positive developments in specific years (e.g., 2011) may inspire confidence among investors and stakeholders, potentially leading to increased interest and support for the company.
#
#
# Negative Growth:
#
# Recognition of predominant negative sentiment in certain years (e.g., 2010, 2012, 2014, 2016) alerts businesses to potential challenges or risks in the market. This insight can prompt businesses to implement risk mitigation strategies, such as diversifying portfolios, hedging against market downturns, or adjusting business operations to adapt to challenging conditions.
# Understanding the reasons behind negative price changes (e.g., market uncertainties, company-specific issues) enables businesses to address underlying issues and work towards restoring investor confidence and market stability.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

numeric_df = df_main.drop(columns=['Date'])

# Calculate correlation matrix
correlation_matrix = numeric_df.corr()

# Create a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap of Tesla Stock Data')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We chose the correlation heatmap because it visually represents the relationships between numeric variables in the dataset, aiding in the identification of patterns and trends within the Tesla stock data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. We can identify the correlations between different variabes
# 2. We can see that some variables exhibit positive or negative correlation with other variables
# 3. It helps us to identify patterns and vriation of variables with other variables

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
numeric_df = df_main.drop(columns=['Date'])

# Create pair plot
sns.pairplot(numeric_df)
plt.title('Pair Plot of Tesla Stock Data')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We picked the pair plot because it provides a comprehensive visualization of the relationships between all pairs of numeric variables in the dataset, aiding in identifying patterns, trends, and potential correlations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. Identification of strong positive or negative correlations between pairs of variables, which indicates how variables move together or in opposite directions.
#
# 2. Recognition of nonlinear relationships between variables, which may suggest more complex interactions or dependencies.
#
# 3. Identification of outliers or unusual data points that deviate significantly from the overall pattern, which may warrant further investigation.
#
# 4. Understanding the distribution shapes of individual variables, which provides insights into their central tendencies and variability.

# %% [markdown]
# ## ***5. Hypothesis Testing***

# %% [markdown]
# ### Based on your chart experiments, define three hypothetical statements from the dataset. In the next three questions, perform hypothesis testing to obtain final conclusion about the statements through your code and statistical testing.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 1

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Null Hypothesis (H0): The opening price of a stock does not have a significant impact on its closing price.
#
#
# Alternative Hypothesis (H1): The opening price of a stock has a significant impact on its closing price.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value
from scipy.stats import pearsonr

# Calculate Pearson correlation coefficient and p-value
corr, p_value = pearsonr(df_main['Open'], df_main['Close'])

print(f"Pearson correlation coefficient: {corr}")
print(f"P-value: {p_value}")
# Out:
# Pearson correlation coefficient: 0.9992332633464368
# P-value: 0.0

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# To obtain the p-value, We conducted a Pearson correlation test between the opening price and the closing price of the stock.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# The Pearson correlation coefficient measures the strength and direction of the linear relationship between two variables, while the associated p-value assesses the significance of this correlation. In this case, a low p-value indicates that the correlation between the opening price and closing price is statistically significant the opening price and closing price of the stock is approximately 0.999, indicating a very strong positive correlation. The p-value of 0.0 suggests that this correlation is statistically significant, providing strong evidence to reject the null hypothesis. Therefore, we can conclude that the opening price of a stock has a significant impact on its closing price.

# %% [markdown]
# ### Hypothetical Statement - 2

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Null Hypothesis (H0): There is no correlation between the volume of trades and the adjusted closing price of a stock.
#
#
# Alternative Hypothesis (H1): There is a correlation between the volume of trades and the adjusted closing price of a stock.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value
from scipy.stats import pearsonr

# Calculate Pearson correlation coefficient and p-value
corr, p_value = pearsonr(df_main['Volume'], df_main['Adj Close'])

print(f"Pearson correlation coefficient: {corr}")
print(f"P-value: {p_value}")
# Out:
# Pearson correlation coefficient: 0.40690720772612643
# P-value: 1.7786813739452075e-68

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
#  We conducted a Pearson correlation test between the volume of trades and the adjusted closing price of the stock

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# We chose the Pearson correlation test because it is commonly used to assess the strength and direction of the linear relationship between two continuous variables. In this case, we are interested in understanding if there is a correlation between the volume of trades (a continuous variable) and the adjusted closing price of the stock (another continuous variable). The Pearson correlation coefficient provides a measure of the strength and direction of this correlation, while the associated p-value helps determine if this correlation is statistically significant. Overall, the Pearson correlation test is suitable for assessing the relationship between these two variables in the context of stock price analysis.
#
# The Pearson correlation coefficient measures the strength and direction of the linear relationship between two variables, while the associated p-value assesses the significance of this correlation. In this case, a low p-value (close to zero) indicates that the correlation between the volume of trades and the adjusted closing price is statistically significant.

# %% [markdown]
# ### Hypothetical Statement - 3

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Null Hypothesis (H0): The highest price of a stock is not a good indicator of its trading range for the day.
#
#
# Alternative Hypothesis (H1): The highest price of a stock is a good indicator of its trading range for the day.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value
from scipy.stats import ttest_ind

# Calculate the trading range (difference between highest and lowest price) and compare it to the highest price
df_main['Trading Range'] = df_main['High'] - df_main['Low']
t_stat, p_value = ttest_ind(df_main['Trading Range'], df_main['High'])

print(f"T-statistic: {t_stat}, p-value: {p_value}")
# Out:
# T-statistic: -55.827673916321444, p-value: 0.0

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# I conducted an independent two-sample t-test using the ttest_ind function from the scipy.stats module. This test compares the means of two independent samples to determine if there is a significant difference between them. In this case, we compared the trading range (difference between highest and lowest price) to the highest price of the stock to assess if the highest price is a good indicator of the trading range for the day.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# I chose the independent two-sample t-test because it is suitable for comparing the means of two independent samples, which is applicable in this scenario where we are comparing the trading range (difference between highest and lowest price) to the highest price of the stock. The t-test helps us determine if the difference between these two samples is statistically significant, which is crucial for assessing if the highest price is a good indicator of the trading range for the day. Overall, the t-test is a standard statistical test for comparing means and is suitable for this hypothesis test.

# %% [markdown]
# ## ***6. Feature Engineering & Data Pre-processing***

# %% [markdown]
# ### 1. Handling Missing Values

# %%
# Handling Missing Values & Missing Value Imputation
df.fillna(df.mean(), inplace=True)

# %% [markdown]
# #### What all missing value imputation techniques have you used and why did you use those techniques?

# %% [markdown]
# We have used Mean Imputation. Mean imputation replaces missing values with the mean of the non-missing values in the column. It is a simple and commonly used method for handling missing data, suitable for variables with a relatively normal distribution.

# %% [markdown]
# ### 2. Handling Outliers

# %%
mean = df.mean()
std_dev = df.std()

# Define a threshold for outlier detection (e.g., 3 times the standard deviation)
threshold = 3

# Calculate Z-scores for each data point
z_scores = (df - mean) / std_dev

# Identify outliers
outliers = (z_scores > threshold) | (z_scores < -threshold)

# Remove outliers
cleaned_df = df[~outliers.any(axis=1)]

# Now 'cleaned_df' contains the DataFrame with outliers removed

# %% [markdown]
# ##### What all outlier treatment techniques have you used and why did you use those techniques?

# %% [markdown]
# We've used Z-score based outlier detection and removal, which identifies and removes data points that are a certain number of standard deviations away from the mean (e.g., 3 times the standard deviation). This technique is effective for normally distributed data and helps mitigate the impact of extreme values on statistical analyses.

# %% [markdown]
# ### 3. Categorical Encoding

# %%
# Encode your categorical columns

# %% [markdown]
# #### What all categorical encoding techniques have you used & why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 4. Textual Data Preprocessing
# (It's mandatory for textual dataset i.e., NLP, Sentiment Analysis, Text Clustering etc.)

# %% [markdown]
# #### 1. Expand Contraction

# %%
# Expand Contraction

# %% [markdown]
# #### 2. Lower Casing

# %%
# Lower Casing

# %% [markdown]
# #### 3. Removing Punctuations

# %%
# Remove Punctuations

# %% [markdown]
# #### 4. Removing URLs & Removing words and digits contain digits.

# %%
# Remove URLs & Remove words and digits contain digits

# %% [markdown]
# #### 5. Removing Stopwords & Removing White spaces

# %%
# Remove Stopwords

# %%
# Remove White spaces

# %% [markdown]
# #### 6. Rephrase Text

# %%
# Rephrase Text

# %% [markdown]
# #### 7. Tokenization

# %%
# Tokenization

# %% [markdown]
# #### 8. Text Normalization

# %%
# Normalizing Text (i.e., Stemming, Lemmatization etc.)

# %% [markdown]
# ##### Which text normalization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 9. Part of speech tagging

# %%
# POS Taging

# %% [markdown]
# #### 10. Text Vectorization

# %%
# Vectorizing Text

# %% [markdown]
# ##### Which text vectorization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 4. Feature Manipulation & Selection

# %% [markdown]
# #### 1. Feature Manipulation

# %%
# Create new date features
df_main['DayOfWeek'] = df_main['Date'].dt.dayofweek
df_main['Month'] = df_main['Date'].dt.month
df_main['Year'] = df_main['Date'].dt.year

# Create price change features
df_main['PriceChange'] = df_main['Close'] - df_main['Open']
df_main['PriceRange'] = df_main['High'] - df_main['Low']

# Create volume-related features
df_main['VolumeChange'] = df_main['Volume'].diff()  # Day-to-day volume change
df_main['VolumeChangePct'] = df_main['Volume'].pct_change()  # Day-to-day volume change percentage




# Create price spread features
df_main['PriceSpread'] = df_main['High'] - df_main['Low']

# Drop original date and redundant columns
df_main.drop(['Date'], axis=1, inplace=True)

# %% [markdown]
# #### 2. Feature Selection

# %%
from sklearn.feature_selection import VarianceThreshold

# Assuming df_main contains the dataset with the features
X = df_main  # Features

# Set a threshold for variance
threshold = 0.1

# Create VarianceThreshold object
selector = VarianceThreshold(threshold)

# Fit the selector to the data
selector.fit(X)

# Get the indices of the selected features
selected_indices = selector.get_support(indices=True)

# Get the names of the selected features
selected_features = X.columns[selected_indices]

# Create a new DataFrame with only the selected features
df_selected = df_main[selected_features]

# %% [markdown]
# ##### What all feature selection methods have you used  and why?

# %% [markdown]
#  I used the VarianceThreshold feature selection method. This method removes features with low variance, assuming that features with low variance are less informative for the model. I chose this method because it is simple and easy to implement, making it suitable for quickly reducing the number of features in the dataset.

# %% [markdown]
# ##### Which all features you found important and why?

# %% [markdown]
#  All features have variance above the specified threshold (0.1 in the example). This means that none of the features had low variance and were deemed uninformative by the method. Therefore, all features are considered important based on this criterion.

# %% [markdown]
# ### 5. Data Transformation

# %% [markdown]
# #### Do you think that your data needs to be transformed? If yes, which transformation have you used. Explain Why?

# %%
# Transform Your data

# %% [markdown]
# ### 6. Data Scaling

# %%
# Scaling your data
from sklearn.preprocessing import MinMaxScaler

# Assuming df_selected contains the dataset with the selected features
X_selected = df_selected  # Features

# Create a MinMaxScaler object
scaler = MinMaxScaler()

# Fit the scaler to the data and transform the data
X_selected_normalized = scaler.fit_transform(X_selected)

# Convert the normalized data back to a DataFrame (if needed)
df_selected_normalized = pd.DataFrame(X_selected_normalized, columns=X_selected.columns)

# Check the min and max values of the normalized data
print("Min values after normalization:")
print(df_selected_normalized.min())
print("\nMax values after normalization:")
print(df_selected_normalized.max())
# Out:
# Min values after normalization:
# Open                  0.0
# High                  0.0
# Low                   0.0
# Close                 0.0
# Volume                0.0
# Adj Close             0.0
# Daily_Price_Change    0.0
# year                  0.0
# price_change          0.0
# DayOfWeek             0.0
# Month                 0.0
# Year                  0.0
# PriceChange           0.0
# PriceRange            0.0
# VolumeChange          0.0
# VolumeChangePct       0.0
# PriceSpread           0.0
# dtype: float64
#
# Max values after normalization:
# Open                  1.0
# High                  1.0
# Low                   1.0
# Close                 1.0
# Volume                1.0
# Adj Close             1.0
# Daily_Price_Change    1.0
# year                  1.0
# price_change          1.0
# DayOfWeek             1.0
# Month                 1.0
# Year                  1.0
# PriceChange           1.0
# PriceRange            1.0
# VolumeChange          1.0
# ...

# %% [markdown]
# ##### Which method have you used to scale you data and why?

# %% [markdown]
# ### 7. Dimesionality Reduction

# %% [markdown]
# ##### Do you think that dimensionality reduction is needed? Explain Why?

# %% [markdown]
# With 13 features, the dataset is not excessively high-dimensional, and many machine learning algorithms should be able to handle this number of features without the need for dimensionality reduction.

# %% [markdown]
# ##### Which dimensionality reduction technique have you used and why? (If dimensionality reduction done on dataset.)

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 8. Data Splitting

# %%
# Split your data to train and test. Choose Splitting ratio wisely.
X = df_selected[['Open','High','Low','Volume']]
y = df_selected['Close']
from sklearn.model_selection import train_test_split
X_train, X_test , y_train, y_test = train_test_split(X,y,random_state = 0)

# %% [markdown]
# ##### What data splitting ratio have you used and why?

# %% [markdown]
#  We have used 75% training data and 25% testing data as it provides enough data for training while still reserving a sufficient amount for testing to evaluate the model's performance

# %% [markdown]
# ### 9. Handling Imbalanced Dataset

# %% [markdown]
# ##### Do you think the dataset is imbalanced? Explain Why.

# %% [markdown]
# Based on the positively skewed distribution of daily stock returns in the dataset, it is likely that the dataset is imbalanced. The positive skewness indicates that there are more occurrences of large positive returns compared to large negative returns. This suggests that one class (possibly the class representing positive stock returns) may have significantly more occurrences than the other class (representing negative stock returns).

# %%
# Handling Imbalanced Dataset (If needed)
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# Create a Random Forest classifier with class_weight='balanced'
clf = RandomForestClassifier(class_weight='balanced', random_state=0)

# %% [markdown]
# ##### What technique did you use to handle the imbalance dataset and why? (If needed to be balanced)

# %% [markdown]
# The technique used to handle the imbalanced dataset is to set the class_weight parameter of the RandomForestClassifier to 'balanced'. This technique is chosen because it automatically adjusts the weights of each class inversely proportional to its frequency in the input data. This means that the algorithm gives more weight to the minority class, helping to address the imbalance issue.

# %% [markdown]
# ## ***7. ML Model Implementation***

# %% [markdown]
# ### ML Model - 1

# %%
# ML Model - 1 Implementation

# Fit the Algorithm

# Predict on the model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import confusion_matrix, top_k_accuracy_score
regressor = LinearRegression()

regressor.fit(X_train,y_train)
print(regressor.coef_)
print(regressor.intercept_)
predicted = regressor.predict(X_test)
print(X_test)

dframe = pd.DataFrame(y_test,predicted)
dfr = pd.DataFrame({'Actual Price':y_test,'Predicted Price':predicted})
print(dfr)
# Out:
# [-5.61128249e-01  8.20244083e-01  7.40523854e-01 -2.44481307e-08]
# 0.03439958011335875
#             Open        High         Low   Volume
# 124    31.260000   32.480000   29.920000  1552600
# 1688  246.110001  258.119995  246.020004  7575500
# 1397  198.970001  205.070007  197.250000  5322200
# 6      16.139999   17.520000   15.570000  7711400
# 1279  264.269989  267.890015  262.000000  2790100
# ...          ...         ...         ...      ...
# 1222  221.000000  237.479996  220.250000  9455900
# 215    27.200001   27.440001   26.170000  1218500
# 536    29.690001   31.299999   29.100000   870100
# 1630  198.080002  202.589996  197.600006  3796900
# 1548  224.169998  225.110001  222.679993  2065500
#
# [423 rows x 4 columns]
#       Actual Price  Predicted Price
# 124      30.090000        31.253574
# 1688    258.000000       255.654999
# 1397    204.990005       202.532384
# 6        17.459999        16.689894
# 1279    263.820007       265.429280
# ...

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Calculate evaluation metrics
mae = mean_absolute_error(y_test, predicted)
mse = mean_squared_error(y_test, predicted)
r2 = r2_score(y_test, predicted)

print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("R-squared:", r2)
metrics = ['Mean Absolute Error', 'Mean Squared Error', 'R-squared']
values = [mae, mse, r2]

plt.figure(figsize=(10, 6))
plt.bar(metrics, values, color='skyblue')
plt.ylabel('Value')
plt.title('Model Evaluation Metrics')
plt.ylim(0, max(values) * 1.2)  # Set y-axis limit to 20% above the maximum value
plt.show()
# Out:
# Mean Absolute Error: 1.0928260736454676
# Mean Squared Error: 2.659515984376391
# R-squared: 0.999703484441961

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression
import pandas as pd

# Define the hyperparameters to tune
param_grid = {
    'fit_intercept': [True, False],
    'copy_X': [True, False]
}

# Create a GridSearchCV object
grid_search = GridSearchCV(estimator=LinearRegression(), param_grid=param_grid, cv=5, scoring='neg_mean_squared_error')

# Fit the GridSearchCV object to the training data
grid_search.fit(X_train, y_train)

# Get the best hyperparameters
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)

# Use the best model to make predictions
best_model = grid_search.best_estimator_
predicted = best_model.predict(X_test)

# Display the actual and predicted prices in a DataFrame
dfr = pd.DataFrame({'Actual Price': y_test, 'Predicted Price': predicted})
print(dfr)
# Out:
# Best Hyperparameters: {'copy_X': True, 'fit_intercept': False}
#       Actual Price  Predicted Price
# 124      30.090000        31.225150
# 1688    258.000000       255.664100
# 1397    204.990005       202.532166
# 6        17.459999        16.668173
# 1279    263.820007       265.435125
# ...            ...              ...
# 1222    236.800003       233.692913
# 215      26.440001        26.599741
# 536      31.170000        30.546679
# 1630    202.490005       201.292272
# 1548    222.929993       223.740636
#
# [423 rows x 2 columns]

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# the hyperparameter optimization technique used is GridSearchCV. GridSearchCV is chosen because it exhaustively searches over a specified hyperparameter grid and evaluates the model performance using cross-validation. This technique helps to find the best combination of hyperparameters that yields the highest model performance according to the specified scoring metric.
#
# GridSearchCV is particularly useful when the hyperparameter space is small and the computational resources allow for an exhaustive search. It provides a systematic way to tune hyperparameters and can help improve the model's performance by finding the optimal set of hyperparameters for the given dataset

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# There was no improvement in the Mean Squared Error (MSE) after hyperparameter optimization using GridSearchCV for the SVR model. The MSE remained the same before and after optimization.
#
# Since the MSE did not change, the Evaluation metric Score Chart would show the same MSE value before and after optimization, indicating no improvement in model performance in terms of MSE.

# %% [markdown]
# ### ML Model - 2

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# ML Model - 2 Implementation

# Fit the Algorithm

# Predict on the model
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

svr_model = SVR(kernel = 'rbf' , C=100,epsilon = 0.1)
svr_model.fit(X_train_scaled,y_train)

predictions = svr_model.predict(X_test_scaled)


predictions_main = pd.DataFrame({'Actual Price':y_test,'Predicted Price':predictions})
predictions_main
# Out:
#       Actual Price  Predicted Price
# 124      30.090000        35.275023
# 1688    258.000000       257.770471
# 1397    204.990005       205.183209
# 6        17.459999        21.995259
# 1279    263.820007       267.594897
# ...            ...              ...
# 1222    236.800003       235.822593
# 215      26.440001        30.736771
# 536      31.170000        34.233379
# 1630    202.490005       203.816045
# 1548    222.929993       226.561722
#
# [423 rows x 2 columns]

# %%
# Visualizing evaluation Metric Score chart
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt

# Calculate Mean Squared Error (MSE), Mean Absolute Error (MAE), and R-squared (R2)
mse = mean_squared_error(y_test, predictions)
mae = mean_absolute_error(y_test, predictions)
r2 = r2_score(y_test, predictions)

# Create a bar chart for the metrics
metrics = ['Mean Squared Error (MSE)', 'Mean Absolute Error (MAE)', 'R-squared (R2)']
values = [mse, mae, r2]

plt.figure(figsize=(10, 6))
plt.bar(metrics, values, color='skyblue')
plt.ylabel('Value')
plt.title('SVR Model Evaluation Metrics')
plt.ylim(0, max(values) * 1.2)  # Set y-axis limit to 20% above the maximum value
plt.show()

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
import pandas as pd

# Scale the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Define the hyperparameter grid
param_grid = {
    'kernel': ['linear', 'rbf', 'poly'],
    'C': [0.1, 1, 10, 100],
    'epsilon': [0.01, 0.1, 1, 10]
}

# Create a GridSearchCV object
grid_search = GridSearchCV(estimator=SVR(), param_grid=param_grid, scoring='neg_mean_squared_error', cv=5)

# Perform the grid search
grid_search.fit(X_train_scaled, y_train)

# Get the best hyperparameters
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)

# Use the best model to make predictions
best_model = grid_search.best_estimator_
predictions = best_model.predict(X_test_scaled)

# Calculate the Mean Squared Error
mse = mean_squared_error(y_test, predictions)
print("Mean Squared Error (MSE):", mse)

# Display the actual and predicted prices in a DataFrame
predictions_main = pd.DataFrame({'Actual Price': y_test, 'Predicted Price': predictions})
print(predictions_main)
# Out:
# Best Hyperparameters: {'C': 100, 'epsilon': 0.1, 'kernel': 'linear'}
# Mean Squared Error (MSE): 2.6779507325335294
#       Actual Price  Predicted Price
# 124      30.090000        31.222309
# 1688    258.000000       255.631015
# 1397    204.990005       202.509533
# 6        17.459999        16.697841
# 1279    263.820007       265.420840
# ...            ...              ...
# 1222    236.800003       233.615221
# 215      26.440001        26.608929
# 536      31.170000        30.550631
# 1630    202.490005       201.298594
# 1548    222.929993       223.756254
#
# [423 rows x 2 columns]

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
#  the hyperparameter optimization technique used is GridSearchCV. GridSearchCV is chosen because it performs an exhaustive search over a specified hyperparameter grid and evaluates the model performance using cross-validation. This technique helps to find the best combination of hyperparameters that yield the highest model performance according to the specified scoring metric.
#
# GridSearchCV is particularly useful when the hyperparameter space is small and the computational resources allow for an exhaustive search. It provides a systematic way to tune hyperparameters and can help improve the model's performance by finding the optimal set of hyperparameters for the given dataset.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# There was no improvement in the Mean Squared Error (MSE) after hyperparameter optimization using GridSearchCV for the SVR model. The MSE remained the same before and after optimization.
#
# Since the MSE did not change, the Evaluation metric Score Chart would show the same MSE value before and after optimization, indicating no improvement in model performance in terms of MSE.

# %% [markdown]
# #### 3. Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# Mean Squared Error (MSE): MSE measures the average squared difference between predicted and actual values. A lower MSE indicates more accurate predictions, helping businesses make better-informed decisions, particularly in stock price prediction, where accuracy is crucial for investment strategies.
#
#
# Mean Absolute Error (MAE): MAE measures the average absolute difference between predicted and actual values. Like MSE, a lower MAE signifies more accurate predictions, which can lead to improved decision-making and potentially more profitable investments for businesses.
#
#
# R-squared (Coefficient of Determination): R-squared indicates the proportion of variance in the dependent variable (e.g., stock prices) that is predictable from the independent variables. A higher R-squared value suggests a better model fit, providing businesses with more reliable insights into stock price movements and aiding in more informed investment decisions.

# %% [markdown]
# ### ML Model - 3

# %%
# ML Model - 3 Implementation

# Fit the Algorithm

# Predict on the model

from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
import pandas as pd

# Assuming X_train, X_test, y_train, y_test are already defined

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

# Fit the Decision Tree Regressor
dt_model = DecisionTreeRegressor()
dt_model.fit(X_train_scaled, y_train)

# Predict using the Decision Tree Regressor
predictions = dt_model.predict(X_test_scaled)

# Create a DataFrame to compare actual and predicted prices
predictions_main = pd.DataFrame({'Actual Price': y_test, 'Predicted Price': predictions})
predictions_main
# Out:
#       Actual Price  Predicted Price
# 124      30.090000        34.330002
# 1688    258.000000       258.679993
# 1397    204.990005       206.550003
# 6        17.459999        19.889999
# 1279    263.820007       269.230011
# ...            ...              ...
# 1222    236.800003       227.059998
# 215      26.440001        30.410000
# 536      31.170000        34.869999
# 1630    202.490005       203.559998
# 1548    222.929993       226.160004
#
# [423 rows x 2 columns]

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart
predictions = dt_model.predict(X_test_scaled)

# Calculate Mean Squared Error
mse = mean_squared_error(y_test, predictions)

# Calculate Mean Absolute Error
mae = mean_absolute_error(y_test, predictions)

# Calculate R-squared
r2 = r2_score(y_test, predictions)

print(f"Mean Squared Error (MSE): {mse}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"R-squared (R2): {r2}")

# # Create Scatter Plot
# plt.figure(figsize=(10, 6))
# plt.scatter(y_test, predictions, color='blue')
# plt.title('Actual vs Predicted Prices')
# plt.xlabel('Actual Price')
# plt.ylabel('Predicted Price')
# plt.show()
metrics = ['Mean Squared Error', 'Mean Absolute Error', 'R-squared']
values = [mse, mae, r2]

# Create a bar chart
plt.figure(figsize=(10, 6))
plt.bar(metrics, values, color=['blue', 'green', 'red'])
plt.ylabel('Metric Value')
plt.title('Evaluation Metrics for Decision Tree Regressor')
plt.show()
# Out:
# Mean Squared Error (MSE): 20.51824082433055
# Mean Absolute Error (MAE): 3.9592199267139474
# R-squared (R2): 0.9977123741072641

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 3 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Assuming X_train, X_test, y_train, y_test are already defined

# Create a pipeline with StandardScaler and DecisionTreeRegressor
pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('dt', DecisionTreeRegressor())
])

# Define the hyperparameters to tune
param_grid = {
    'dt__max_depth': [None, 5, 10, 15],
    'dt__min_samples_split': [2, 5, 10],
    'dt__min_samples_leaf': [1, 2, 4]
}

# Perform GridSearchCV
grid_search = GridSearchCV(pipeline, param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(X_train, y_train)

# Get the best model from GridSearchCV
best_model = grid_search.best_estimator_
predictions = best_model.predict(X_test)

# Create a DataFrame to compare actual and predicted prices
predictions_df = pd.DataFrame({'Actual Price': y_test, 'Predicted Price': predictions})

# Display the DataFrame
predictions_df
# Out:
#       Actual Price  Predicted Price
# 124      30.090000        30.560000
# 1688    258.000000       250.962502
# 1397    204.990005       204.697998
# 6        17.459999        17.890000
# 1279    263.820007       266.845009
# ...            ...              ...
# 1222    236.800003       231.457497
# 215      26.440001        27.152857
# 536      31.170000        29.487000
# 1630    202.490005       201.088000
# 1548    222.929993       223.449999
#
# [423 rows x 2 columns]

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# We used GridSearchCV for hyperparameter optimization. GridSearchCV is a commonly used technique for hyperparameter tuning because it exhaustively searches through a specified parameter grid and evaluates the model performance using cross-validation. It considers all possible combinations of hyperparameters in the grid and selects the best combination based on a specified scoring metric.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# After hyperparameter optimization using GridSearchCV, there was a slight improvement in the model's performance. The optimization process helped fine-tune the hyperparameters of the Decision Tree Regressor, resulting in a slightly better predictive capability. While the improvement may be modest, it indicates that the model is better optimized to make more accurate predictions, which can be valuable in stock price prediction tasks.

# %% [markdown]
# ### 1. Which Evaluation metrics did you consider for a positive business impact and why?

# %% [markdown]
# We can consider the Mean Absolute Error (MAE) as a key evaluation metric for a positive business impact. MAE measures the average magnitude of the errors in the model's predictions, which is important for assessing the model's accuracy in predicting stock prices.
#
# By focusing on minimizing MAE, you can ensure that the model's predictions are as close as possible to the actual stock prices, which is crucial for making informed trading decisions and maximizing profits.

# %% [markdown]
# ### 2. Which ML model did you choose from the above created models as your final prediction model and why?

# %% [markdown]
# We chose linear regression as the final prediction model for stock price prediction. Despite its simplicity, linear regression offers several advantages that make it suitable for this task:
#
# Interpretability: Linear regression provides easily interpretable coefficients for each feature, allowing us to understand the impact of each feature on the predicted stock price.
#
# Assumption of Linearity: The relationships between the input features (e.g., opening price, closing price) and the target variable (stock price) are assumed to be approximately linear, which is a reasonable assumption in many financial modeling scenarios.
#
# Computational Efficiency: Linear regression is computationally efficient and can handle large datasets with many features, making it practical for stock price prediction.
#
# Baseline Model: Linear regression serves as a good baseline model for comparison with more complex models, providing a simple and transparent benchmark for evaluating model performance.

# %% [markdown]
# ### 3. Explain the model which you have used and the feature importance using any model explainability tool?

# %% [markdown]
# In our stock price prediction model using linear regression, we chose linear regression for its simplicity and interpretability. Linear regression assumes that the relationship between the input features (such as opening price, closing price, etc.) and the target variable (stock price) is linear, which is often a reasonable assumption in financial markets.
#
# To explain the model and feature importance, we can look at the coefficients assigned to each feature. These coefficients indicate the impact of each feature on the predicted stock price. For example, if the coefficient for the opening price is higher than the coefficient for the closing price, it suggests that the opening price has a stronger influence on the stock price prediction.
#
# Using a model explainability tool, we can visualize the feature importance by plotting the coefficients. This visualization helps us understand which features are driving the predictions and their relative importance. For instance, if the volume of trades has a high coefficient, it indicates that trading volume is a significant factor in predicting stock prices.
#
# Overall, linear regression provides a straightforward way to understand the relationship between features and stock prices, making it a valuable tool for stock price prediction.

# %% [markdown]
# ## ***8.*** ***Future Work (Optional)***

# %% [markdown]
# ### 1. Save the best performing ml model in a pickle file or joblib file format for deployment process.

# %%
# Save the File

# %% [markdown]
# ### 2. Again Load the saved model file and try to predict unseen data for a sanity check.

# %%
# Load the File and predict unseen data.

# %% [markdown]
# ### ***Congrats! Your model is successfully created and ready for deployment on a live server for a real user interaction !!!***

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The stock price prediction project utilized linear regression to forecast stock prices based on historical data. It involved preprocessing the dataset, including features such as opening price, closing price, highest price, lowest price, volume, and adjusted closing price. The model was trained and evaluated using metrics like Mean Squared Error (MSE), Mean Absolute Error (MAE), and R-squared. Hyperparameter optimization techniques like GridSearchCV were employed to fine-tune the model, resulting in a slight improvement in performance. Feature importance analysis was conducted to understand the factors influencing stock price predictions. Overall, the project highlights the application of machine learning in stock price forecasting and the importance of model interpretability and performance evaluation in financial modeling.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
